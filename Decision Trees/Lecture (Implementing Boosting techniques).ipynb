# %%
# %run "Lecture_20 (Implementing Regression Tree).ipynb"
# %run "Lecture_21 (Implementing Classification Trees).ipynb"
# %run "Lecture (Implementing Random Forests).ipynb"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %% [markdown]
# ## Gradient boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
#fitting with default hyperparameters
gb_clf = GradientBoostingClassifier()
gb_clf.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
accuracy_score(y_test, gb_clf.predict(X_test))
# Out:
# 0.5784313725490197

# %%
#tuning parameters; learning rate = lambda/shrinkage parameter
gb_clf2 = GradientBoostingClassifier(learning_rate = 0.02, n_estimators = 1000, max_depth = 1)
gb_clf2.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.02, max_depth=1, n_estimators=1000)

# %%
accuracy_score(y_test, gb_clf2.predict(X_test))
# Out:
# 0.6176470588235294

# %% [markdown]
# #### You can apply gridsearch to find the optimal parameters for the model

# %% [markdown]
# ## Ada(ptive) boosting

# %%
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# #### The adaboost will be used in decision trees classfiers algorithm

# %%
ada_clf = AdaBoostClassifier(learning_rate = 0.02, n_estimators = 5000)
ada_clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(learning_rate=0.02, n_estimators=5000)

# %%
accuracy_score(y_test, ada_clf.predict(X_test))
# Out:
# 0.6274509803921569

# %% [markdown]
# #### You can implement adaboost in randomforest algorithms

# %%
#you can specify the estimator when assigning an object classifier; rf_clf is the randomforest model from previous lectures
ada_rf = AdaBoostClassifier(rf_clf, learning_rate = 0.02, n_estimators = 500)
ada_rf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(base_estimator=RandomForestClassifier(n_estimators=250,
#                                                          random_state=42),
#                    learning_rate=0.02, n_estimators=500)

# %%
accuracy_score(y_test, ada_rf.predict(X_test))
# Out:
# 0.6470588235294118

# %% [markdown]
# ## XG (extreme gradient) Boosting

# %%
import xgboost as xgb

# %% [markdown]
# #### Paramteter tuning
#
# 1. General parameters = guide the overall functioning
# 2. Booster parameters = guide the individual booster (tree/regression) at each step
# 3. Learning Task parameters = guide the optmization performed

# %%
xgb_clf = xgb.XGBClassifier(max_depth = 5, n_estimators = 10000, learning_rate = 0.3, n_jobs = -1)
xgb_clf.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:17:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
# ...

# %%
accuracy_score(y_test, xgb_clf.predict(X_test))
# Out:
# 0.6666666666666666

# %%
#plot variable importance
xgb.plot_importance(xgb_clf)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# #### Grid search to optimize hyperparameters

# %%
xgb_clf = xgb.XGBClassifier(n_estimators = 250, learning_rate = 0.1, random_state = 42)

# %%
#define parameter grids
param_test1 = {
    "max_depth": range(3,10, 2),
    "gamma": [0.1, 0.2, 0.3], #similar to min_sample_split of decision trees algorithms
    "subsample": [0.8, 0.9], #for each tree being built, use 80% or 90% of the data
    "colsample_bytree": [0.8, 0.9], #columns sample = use 80% or 90% of X variables for each tree
    "reg_alpha": [1e-2, 0.1, 1] #regularization L1 parameter  
}
param_test1
# Out:
# {'max_depth': range(3, 10, 2),
#  'gamma': [0.1, 0.2, 0.3],
#  'subsample': [0.8, 0.9],
#  'colsample_bytree': [0.8, 0.9],
#  'reg_alpha': [0.01, 0.1, 1]}

# %%
grid_search = GridSearchCV(xgb_clf, param_test1, n_jobs = -1, cv = 5, scoring = "accuracy")
grid_search.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:28:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
# ...

# %%
grid_search.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'gamma': 0.1,
#  'max_depth': 3,
#  'reg_alpha': 0.1,
#  'subsample': 0.8}

# %%
cvxg_clf = grid_search.best_estimator_

# %%
#the accuracy decreased because we decrease number of trees for computational time saving.
accuracy_score(y_test, cvxg_clf.predict(X_test))
# Out:
# 0.6176470588235294
